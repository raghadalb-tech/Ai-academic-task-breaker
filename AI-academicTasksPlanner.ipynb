# %%
# !pip install huggingface_hub

from huggingface_hub import InferenceClient

token = input("Enter your Hugging Face token: ")

client = InferenceClient(
    model="meta-llama/Llama-3.2-3B-Instruct",
    token=token
)

def generate_subtasks(task):
    prompt = f"Break the following academic task into clear, structured subtasks in English:\n{task}"
    response = client.chat.completions.create(
        model="meta-llama/Llama-3.2-3B-Instruct",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message["content"]

task = input("Enter your academic task: ")
result = generate_subtasks(task)
print("\nSubtasks:")
print(result)
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.11.12)
# Enter your Hugging Face token: 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
# Enter your academic task: study for networks final exam
#
# Subtasks:
# Here's a structured approach to studying for a networks final exam:
#
# **I. Review Course Materials (Week 1-2)**
#
# 1.1. Gather all course materials, including:
# 	* Class notes
# 	* Lecture slides
# 	* Handouts
# 	* Textbooks
# 2.1. Re-read and summarize key concepts, including:
# 	* Network fundamentals (topology, protocols, etc.)
# 	* Network architectures (LAN, WAN, etc.)
# 	* Network devices (routers, switches, etc.)
# 3.1. Identify key terms and concepts that need review
#
# **II. Identify Study Objectives (Week 1)**
#
# 1.1. Review the course syllabus and identify key topics that will be covered on the final exam
# 1.2. Create a list of key concepts and topics that need to be covered
# 1.3. Prioritize study objectives based on importance and difficulty
#
# **III. Create a Study Plan (Week 1-2)**
#
# 1.1. Set a study schedule and timeline
# 1.2. Break down study material into manageable chunks (e.g., one topic per study session)
# 1.3. Allocate specific time slots for each study session
# 1.4. Review and adjust the study plan as needed
#
# **IV. Develop Study Strategies (Week 2-3)**
#
# 1.1. Develop a note-taking system to review and summarize key concepts
# 1.2. Create flashcards to review key terms and concepts
# 1.3. Practice problems and past exams to reinforce understanding
# 1.4. Use online resources, such as video lectures or study groups, to supplement learning
#
# **V. Practice and Review (Week 3-4)**
#
# 1.1. Regularly review and practice key concepts and topics
# 1.2. Use practice problems and past exams to reinforce understanding
# 1.3. Join a study group or online community to discuss and review material
# 1.4. Take practice quizzes or exams to assess understanding and identify areas for improvement
#
# **VI. Final Review and Practice (Week 4)**
#
# 1.1. Review all study material and practice problems one last time
# 1.2. Focus on areas where improvement is needed
# 1.3. Practice under timed conditions to simulate the actual exam experience
# 1.4. Get plenty of rest and review material before the exam day
#
# **VII. Take the Final Exam (Exam Day)**
#
# 1.1. Arrive at the exam location early and prepared
# 1.2. Read and follow all exam instructions carefully
# 1.3. Manage time effectively and answer questions to the best of ability
# 1.4. Review and reflect on the exam experience to identify areas for improvement.
